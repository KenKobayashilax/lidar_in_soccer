# %%
#after running this, no need to restart the kurnel when you modify other files.
# %load_ext autoreload
# %autoreload 2

# %%
import os
import open3d
from settings import DATA_PATH
import clusterization.clusterize as clusterizer
import numpy as np
from utils.visualizer import save_camera_params
from utils.handling_cluster import visualize_by_cluster, crop_cluster
from detection.detect import compute_nearest_cluster,compute_nearest_multi_cluster, change_multi_cluster_color, change_cluster_color, compute_bbox
import utils.visualizer as visualizer

data_type_name_pcd = "LIVOX_Hallway_pcds"
experiment_name = "2Player_jogging_medium"
dir_name = "res100ms_start13.5s"

#directory path of pcd files
directory_path = os.path.join(DATA_PATH, data_type_name_pcd, experiment_name, dir_name)
#'{DATA_PATH}/LIVOX_Hallway_pcds/jogging_fast_4th/res100ms_start13.5s'

#add save_path
experiment_name_clustered = experiment_name + "_clustered"
dir_name_clustered= dir_name + "_clustered"
folder_clustered = os.path.join(DATA_PATH, data_type_name_pcd, experiment_name_clustered, dir_name_clustered)

if not os.path.exists(folder_clustered):
    os.makedirs(folder_clustered)

# make the list of files
file_list = []
for filename in os.listdir(directory_path):
    if os.path.isfile(os.path.join(directory_path, filename)):
        file_list.append(os.path.join(directory_path, filename))
        
#select your view point and close your window.
pcd = open3d.io.read_point_cloud(file_list[0])
cam_params = save_camera_params(pcd)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# set the view point and close the window

# %%
#add save_path
experiment_name_tracked = experiment_name + "_bbox_tracked"
dir_name_tracked= dir_name + "_bbox_tracked"
folder_tracked = os.path.join(DATA_PATH, data_type_name_pcd, experiment_name_tracked, dir_name_tracked)

if not os.path.exists(folder_tracked):
    os.makedirs(folder_tracked)

#initialization
eps = 0.5
center_prev = np.zeros(3) #initialize center of human cluster in previous frame
center_prev_list = []

#clusterize each files and visualize.
for i, pcd_file in enumerate(file_list):
    pcd = open3d.io.read_point_cloud(pcd_file)
    
    pcd_clustered = folder_clustered + "/" + os.path.basename(pcd_file) #pcd_clustered_save_path   
    
    #clusterization
    pcd, labels = clusterizer.clusterize(pcd, eps=eps,
                             time_duration=None, #time duration that each windows open for. If you choose None, close window manually.
                             window_name=os.path.basename(pcd_file), #window name changes accorrding to file name.
                             cam_params=cam_params,#camera parameter(view point) you selected
                             save_path=pcd_clustered,
                             visualize=False
                             ) 
    
    
    human_labels = compute_bbox(pcd,labels)

    
    
    #select human cluster in first frame
    #select cluster id in comand line. check each window name.
    
    for j, l in enumerate(human_labels):
        if i==0:
            #visualize_by_cluster(pcd, labels)
            cluster_id = l
        else:
            cluster_id = compute_nearest_cluster(pcd, labels, center_prev)
        
        #color of points in cluster_id is changed into red.
        pcd = change_cluster_color(pcd, labels, cluster_id=cluster_id)
        visualizer.visualize(pcd, time_duration=0.5, cam_params=cam_params)
        
        #crop (and save) selected cluser
        cropped_pcd = crop_cluster(pcd, labels, cluster_id=cluster_id, visualize=False)
        
        #compute center and distance between two centers
        center_tmp = cropped_pcd.get_center()
        current_dist = np.linalg.norm (center_prev - center_tmp)
        
        #update center if current cluster is close to previous one"
        if current_dist < 3:
            center_prev = center_tmp
        
        #update center if current cluster is close to previous one
        center_prev = center_tmp
        
        
        # save the cropped cluster(pcd, save_path)
        cluster_tracked = str(j) + "_class"
        class_folder_tracked = os.path.join(folder_tracked, cluster_tracked)
        
        if not os.path.exists(class_folder_tracked):
            os.makedirs(class_folder_tracked)
            
        save_path_tracked = class_folder_tracked + '/' + os.path.basename(pcd_file) 
        if save_path_tracked != None:
            open3d.io.write_point_cloud(save_path_tracked, cropped_pcd)
    

# #label_list could be used later.
# Out:
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 10
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# filtered_labels: [3, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [4, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [4, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [3, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.01y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 4, 7, 11]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.01y + 1.00z + -2.29 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [0, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 10
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# filtered_labels: [2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [2, 7]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [3, 4, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [3, 4, 9]
# Plane equation: -0.00x + -0.01y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [3, 4, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [4, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.01y + 1.00z + -2.29 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [5, 11]
# Plane equation: -0.00x + -0.01y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [4, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [3, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [1]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [0, 6, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 10
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# filtered_labels: [0, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [2, 7]
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# num_clusters 10
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# filtered_labels: [1, 4]
# Plane equation: 0.00x + -0.01y + 1.00z + -2.28 = 0
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [3, 4, 10]
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# num_clusters 17
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# Cluster 16 Bounding Box:
# filtered_labels: [5, 11, 12]
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [5, 8, 11]
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# Plane equation: -0.00x + -0.01y + 1.00z + 1.04 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [1, 6, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [1, 3, 5, 11]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 5, 7]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 4, 7]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 4, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 6, 9, 12]
# Plane equation: -0.00x + -0.01y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [0, 3, 6, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 2, 7]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [1, 3, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.01y + 1.00z + -2.29 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 5, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [6, 8, 10, 11]
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [4, 5, 8, 11]
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [1, 3, 8, 12]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 1, 4, 6, 7, 12]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 2, 6, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 1, 5, 10, 11, 14]
# Plane equation: -0.00x + -0.01y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [0, 1, 5, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [2, 8, 9, 12]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [2, 4, 7, 9, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 7, 9, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 2, 6, 7, 9]
# Plane equation: -0.00x + -0.01y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 5, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [5, 7, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [2, 3, 4, 7]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 1, 3, 6, 12]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [1, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 1, 4, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 1, 4, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 17
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# Cluster 16 Bounding Box:
# filtered_labels: [0, 1, 4, 16]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [1, 7, 9, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [1, 6, 9, 14]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 6, 7, 9, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [2, 4, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [6, 7, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [2, 4, 7, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 3, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 2, 5, 9, 12]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [4, 7, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [1, 7, 8, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [2, 4, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 4, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [0, 3, 4, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [0, 2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 3, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [2, 3, 6, 9, 11]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 2, 4, 5, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 20
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# Cluster 16 Bounding Box:
# Cluster 17 Bounding Box:
# Cluster 18 Bounding Box:
# Cluster 19 Bounding Box:
# filtered_labels: [0, 2, 3, 5, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [3, 4, 6, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [3, 5, 7]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [4, 7, 9]
# Plane equation: -0.00x + -0.01y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [0, 3, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [0, 2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [1, 2, 6]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 2, 5, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 22
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# Cluster 16 Bounding Box:
# Cluster 17 Bounding Box:
# Cluster 18 Bounding Box:
# Cluster 19 Bounding Box:
# Cluster 20 Bounding Box:
# Cluster 21 Bounding Box:
# filtered_labels: [0, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [0, 2, 3, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [3, 5, 7]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# ...
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 4, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [1, 2, 4, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 3, 4, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 20
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# Cluster 16 Bounding Box:
# Cluster 17 Bounding Box:
# Cluster 18 Bounding Box:
# Cluster 19 Bounding Box:
# filtered_labels: [1, 5, 12]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [4, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 20
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# Cluster 16 Bounding Box:
# Cluster 17 Bounding Box:
# Cluster 18 Bounding Box:
# Cluster 19 Bounding Box:
# filtered_labels: [8, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [6, 10, 12]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [4, 7, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 4, 13]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [1, 2, 5, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 17
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# Cluster 16 Bounding Box:
# filtered_labels: [1, 2, 5]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 4, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [1, 4]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 3, 4, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 4]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 4, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [1, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 18
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# Cluster 16 Bounding Box:
# Cluster 17 Bounding Box:
# filtered_labels: [6, 8, 10]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 13
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# filtered_labels: [5, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.03 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [5, 7, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 16
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# Cluster 15 Bounding Box:
# filtered_labels: [4, 9, 11, 14]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [1, 2, 4, 8]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 4, 13]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 15
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# Cluster 14 Bounding Box:
# filtered_labels: [1, 4, 9]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 4]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 11
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# filtered_labels: [1, 3, 4]
# Plane equation: -0.00x + -0.01y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.29 = 0
# num_clusters 14
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# Cluster 12 Bounding Box:
# Cluster 13 Bounding Box:
# filtered_labels: [1, 2, 3, 4]
# Plane equation: -0.00x + -0.02y + 1.00z + 1.04 = 0
# Plane equation: 0.00x + -0.02y + 1.00z + -2.28 = 0
# num_clusters 12
# Cluster -1 Bounding Box:
# Cluster 0 Bounding Box:
# Cluster 1 Bounding Box:
# Cluster 2 Bounding Box:
# Cluster 3 Bounding Box:
# Cluster 4 Bounding Box:
# Cluster 5 Bounding Box:
# Cluster 6 Bounding Box:
# Cluster 7 Bounding Box:
# Cluster 8 Bounding Box:
# Cluster 9 Bounding Box:
# Cluster 10 Bounding Box:
# Cluster 11 Bounding Box:
# filtered_labels: [1, 4]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 46
#      44 #color of points in cluster_id is changed into red.
#      45 pcd = change_cluster_color(pcd, labels, cluster_id=cluster_id)
# ---> 46 visualizer.visualize(pcd, time_duration=0.5, cam_params=cam_params)
#      48 #crop (and save) selected cluser
#      49 cropped_pcd = crop_cluster(pcd, labels, cluster_id=cluster_id, visualize=False)
#
# File d:\TUM File\semester5\pratical laser scanning\lidar_in_soccer\utils\visualizer.py:26, in visualize(pcd_list, time_duration, window_name, width, height, cam_params)
#      23 vis.update_renderer()
#      25 # 待機
# ---> 26 time.sleep(time_duration)
#      28 # ウィンドウを閉じる
#      29 vis.destroy_window()
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
